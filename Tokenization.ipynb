# %%
# Tokenization of paragraphs/sentences
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
paragraph = '''It started before I was born. My biological mother was a young, unwed college graduate student, and she decided 
               to put me up for adoption. She felt very strongly that I should be adopted by college graduates, so everything 
               was all set for me to be adopted at birth by a lawyer and his wife. Except that when I popped out they decided 
               at the last minute that they really wanted a girl. So my parents, who were on a waiting list, got a call in the 
               middle of the night asking: “We have an unexpected baby boy; do you want him?” They said: “Of course.” My 
               biological mother later found out that my mother had never graduated from college and that my father had never 
               graduated from high school. She refused to sign the final adoption papers.She only relented a few months later 
               when my parents promised that I would someday go to college.'''

# %%
# Tokenizing sentences
sentences = nltk.sent_tokenize(paragraph)

# %%
# Return all the sentences present in the paragraph
sentences
# Out:
# ['It started before I was born.',
#  'My biological mother was a young, unwed college graduate student, and she decided \n               to put me up for adoption.',
#  'She felt very strongly that I should be adopted by college graduates, so everything \n               was all set for me to be adopted at birth by a lawyer and his wife.',
#  'Except that when I popped out they decided \n               at the last minute that they really wanted a girl.',
#  'So my parents, who were on a waiting list, got a call in the \n               middle of the night asking: “We have an unexpected baby boy; do you want him?” They said: “Of course.” My \n               biological mother later found out that my mother had never graduated from college and that my father had never \n               graduated from high school.',
#  'She refused to sign the final adoption papers.She only relented a few months later \n               when my parents promised that I would someday go to college.']

# %%
# Tokenizing words
words = nltk.word_tokenize(paragraph)

# %%
# Return all the words present in the paragraph (contain duplicates also)
words
# Out:
# ['It',
#  'started',
#  'before',
#  'I',
#  'was',
#  'born',
#  '.',
#  'My',
#  'biological',
#  'mother',
#  'was',
#  'a',
#  'young',
#  ',',
#  'unwed',
#  'college',
#  'graduate',
#  'student',
#  ',',
#  'and',
#  'she',
#  'decided',
#  'to',
#  'put',
#  'me',
#  'up',
#  'for',
#  'adoption',
#  '.',
#  'She',
#  'felt',
#  'very',
#  'strongly',
#  'that',
#  'I',
#  'should',
#  'be',
#  'adopted',
#  'by',
#  'college',
#  'graduates',
#  ',',
#  'so',
#  'everything',
#  'was',
#  'all',
#  'set',
#  'for',
#  'me',
#  'to',
#  'be',
#  'adopted',
#  'at',
#  'birth',
#  'by',
#  'a',
#  'lawyer',
#  'and',
#  'his',
#  'wife',
#  '.',
#  'Except',
#  'that',
#  'when',
#  'I',
#  'popped',
#  'out',
#  'they',
#  'decided',
#  'at',
#  'the',
#  'last',
#  'minute',
#  'that',
#  'they',
#  'really',
#  'wanted',
#  'a',
#  'girl',
#  '.',
#  'So',
#  'my',
#  'parents',
#  ',',
#  'who',
#  'were',
#  'on',
#  'a',
#  'waiting',
#  'list',
#  ',',
#  'got',
#  'a',
#  'call',
#  'in',
#  'the',
#  'middle',
#  'of',
#  'the',
#  'night',
#  'asking',
#  ':',
#  '“',
#  'We',
#  'have',
#  'an',
#  'unexpected',
#  'baby',
#  'boy',
#  ';',
#  'do',
#  'you',
#  'want',
#  'him',
#  '?',
#  '”',
#  'They',
#  'said',
#  ':',
#  '“',
#  'Of',
#  'course.',
#  '”',
#  'My',
#  'biological',
#  'mother',
#  'later',
#  'found',
#  'out',
#  'that',
#  'my',
#  'mother',
#  'had',
#  'never',
#  'graduated',
#  'from',
#  'college',
#  'and',
#  'that',
#  'my',
#  'father',
#  'had',
#  'never',
#  'graduated',
#  'from',
#  'high',
#  'school',
#  '.',
#  'She',
#  'refused',
#  'to',
#  'sign',
#  'the',
#  'final',
#  'adoption',
#  'papers.She',
#  'only',
#  'relented',
#  'a',
#  'few',
#  'months',
#  'later',
#  'when',
#  'my',
#  'parents',
#  'promised',
#  'that',
#  'I',
#  'would',
#  'someday',
#  'go',
#  'to',
#  'college',
#  '.']

# %%
from collections import Counter

# %%
num_words = Counter(words)

# %%
# unique words present in parqagraph and number of times they are present
num_words
# Out:
# Counter({'It': 1,
#          'started': 1,
#          'before': 1,
#          'I': 4,
#          'was': 3,
#          'born': 1,
#          '.': 6,
#          'My': 2,
#          'biological': 2,
#          'mother': 3,
#          'a': 6,
#          'young': 1,
#          ',': 5,
#          'unwed': 1,
#          'college': 4,
#          'graduate': 1,
#          'student': 1,
#          'and': 3,
#          'she': 1,
#          'decided': 2,
#          'to': 4,
#          'put': 1,
#          'me': 2,
#          'up': 1,
#          'for': 2,
#          'adoption': 2,
#          'She': 2,
#          'felt': 1,
#          'very': 1,
#          'strongly': 1,
#          'that': 6,
#          'should': 1,
#          'be': 2,
#          'adopted': 2,
#          'by': 2,
#          'graduates': 1,
#          'so': 1,
#          'everything': 1,
#          'all': 1,
#          'set': 1,
#          'at': 2,
#          'birth': 1,
#          'lawyer': 1,
#          'his': 1,
#          'wife': 1,
#          'Except': 1,
#          'when': 2,
#          'popped': 1,
#          'out': 2,
#          'they': 2,
#          'the': 4,
#          'last': 1,
#          'minute': 1,
#          'really': 1,
#          'wanted': 1,
#          'girl': 1,
#          'So': 1,
#          'my': 4,
#          'parents': 2,
#          'who': 1,
#          'were': 1,
#          'on': 1,
#          'waiting': 1,
#          'list': 1,
#          'got': 1,
#          'call': 1,
#          'in': 1,
#          'middle': 1,
#          'of': 1,
#          'night': 1,
#          'asking': 1,
#          ':': 2,
#          '“': 2,
#          'We': 1,
#          'have': 1,
#          'an': 1,
#          'unexpected': 1,
#          'baby': 1,
#          'boy': 1,
#          ';': 1,
#          'do': 1,
#          'you': 1,
#          'want': 1,
#          'him': 1,
#          '?': 1,
#          '”': 2,
#          'They': 1,
#          'said': 1,
#          'Of': 1,
#          'course.': 1,
#          'later': 2,
#          'found': 1,
#          'had': 2,
#          'never': 2,
#          'graduated': 2,
#          'from': 2,
#          'father': 1,
#          'high': 1,
#          'school': 1,
#          'refused': 1,
#          'sign': 1,
#          'final': 1,
#          'papers.She': 1,
#          'only': 1,
#          'relented': 1,
#          'few': 1,
#          'months': 1,
#          'promised': 1,
#          'would': 1,
#          'someday': 1,
#          'go': 1})

# %%
# sorting words in descending order of number of times they occur
dict(sorted(num_words.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'.': 6,
#  'a': 6,
#  'that': 6,
#  ',': 5,
#  'I': 4,
#  'college': 4,
#  'to': 4,
#  'the': 4,
#  'my': 4,
#  'was': 3,
#  'mother': 3,
#  'and': 3,
#  'My': 2,
#  'biological': 2,
#  'decided': 2,
#  'me': 2,
#  'for': 2,
#  'adoption': 2,
#  'She': 2,
#  'be': 2,
#  'adopted': 2,
#  'by': 2,
#  'at': 2,
#  'when': 2,
#  'out': 2,
#  'they': 2,
#  'parents': 2,
#  ':': 2,
#  '“': 2,
#  '”': 2,
#  'later': 2,
#  'had': 2,
#  'never': 2,
#  'graduated': 2,
#  'from': 2,
#  'It': 1,
#  'started': 1,
#  'before': 1,
#  'born': 1,
#  'young': 1,
#  'unwed': 1,
#  'graduate': 1,
#  'student': 1,
#  'she': 1,
#  'put': 1,
#  'up': 1,
#  'felt': 1,
#  'very': 1,
#  'strongly': 1,
#  'should': 1,
#  'graduates': 1,
#  'so': 1,
#  'everything': 1,
#  'all': 1,
#  'set': 1,
#  'birth': 1,
#  'lawyer': 1,
#  'his': 1,
#  'wife': 1,
#  'Except': 1,
#  'popped': 1,
#  'last': 1,
#  'minute': 1,
#  'really': 1,
#  'wanted': 1,
#  'girl': 1,
#  'So': 1,
#  'who': 1,
#  'were': 1,
#  'on': 1,
#  'waiting': 1,
#  'list': 1,
#  'got': 1,
#  'call': 1,
#  'in': 1,
#  'middle': 1,
#  'of': 1,
#  'night': 1,
#  'asking': 1,
#  'We': 1,
#  'have': 1,
#  'an': 1,
#  'unexpected': 1,
#  'baby': 1,
#  'boy': 1,
#  ';': 1,
#  'do': 1,
#  'you': 1,
#  'want': 1,
#  'him': 1,
#  '?': 1,
#  'They': 1,
#  'said': 1,
#  'Of': 1,
#  'course.': 1,
#  'found': 1,
#  'father': 1,
#  'high': 1,
#  'school': 1,
#  'refused': 1,
#  'sign': 1,
#  'final': 1,
#  'papers.She': 1,
#  'only': 1,
#  'relented': 1,
#  'few': 1,
#  'months': 1,
#  'promised': 1,
#  'would': 1,
#  'someday': 1,
#  'go': 1}
